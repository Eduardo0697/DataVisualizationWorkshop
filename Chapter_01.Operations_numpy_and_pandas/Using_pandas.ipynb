# %%
import pandas as pd

# %%
file = '../Datasets/world_population.csv'
# index_col=0, especifica que queremos cargar la primer columna como indice en lugar de uno autogeneradp 0...n
dataset = pd.read_csv(file, index_col=0)

# %%
dataset.head()
# Out:
#              Country Code                                     Indicator Name  \
# Country Name
# Aruba                 ABW  Population density (people per sq. km of land ...
# Andorra               AND  Population density (people per sq. km of land ...
# Afghanistan           AFG  Population density (people per sq. km of land ...
# Angola                AGO  Population density (people per sq. km of land ...
# Albania               ALB  Population density (people per sq. km of land ...
#
#              Indicator Code  1960        1961        1962        1963  \
# Country Name
# Aruba           EN.POP.DNST   NaN  307.972222  312.366667  314.983333
# Andorra         EN.POP.DNST   NaN   30.587234   32.714894   34.914894
# Afghanistan     EN.POP.DNST   NaN   14.038148   14.312061   14.599692
# Angola          EN.POP.DNST   NaN    4.305195    4.384299    4.464433
# Albania         EN.POP.DNST   NaN   60.576642   62.456898   64.329234
#
# ...

# %%
dataset.tail()
# Out:
#                  Country Code  \
# Country Name
# Yemen, Rep.               YEM
# South Africa              ZAF
# Congo, Dem. Rep.          COD
# Zambia                    ZMB
# Zimbabwe                  ZWE
#
#                                                      Indicator Name  \
# Country Name
# Yemen, Rep.       Population density (people per sq. km of land ...
# South Africa      Population density (people per sq. km of land ...
# Congo, Dem. Rep.  Population density (people per sq. km of land ...
# Zambia            Population density (people per sq. km of land ...
# Zimbabwe          Population density (people per sq. km of land ...
#
#                  Indicator Code  1960       1961       1962       1963  \
# Country Name
# Yemen, Rep.         EN.POP.DNST   NaN   9.946897  10.112857  10.283730
# South Africa        EN.POP.DNST   NaN  14.796892  15.216878  15.609838
# Congo, Dem. Rep.    EN.POP.DNST   NaN   6.897825   7.075824   7.261381
# ...

# %%
dataset.shape
# Out:
# (264, 60)

# %%
# Calcular la media de la columna '1961'
dataset["1961"].mean()
# Out:
# 176.91514132840555

# %%
# calculating the mean for 2015 column
dataset["2015"].mean()
# Out:
# 368.70660104001837

# %%
# para obtener la media de cada pais (fila) especificamos que calcule la media en el axis=1
dataset.mean(axis=1).head(10)
# Out:
# Country Name
# Aruba                   413.944949
# Andorra                 106.838839
# Afghanistan              25.373379
# Angola                    9.649583
# Albania                  99.159197
# Arab World               16.118586
# United Arab Emirates     31.321721
# Argentina                11.634028
# Armenia                 103.415539
# American Samoa          211.855636
# dtype: float64

# %%
# con axis=0, especificamos que queremos la media pero por columna , en este caso seria de cada año de todos los paises
dataset.mean(axis=0).tail(10)
# Out:
# 2007    331.995474
# 2008    338.688417
# 2009    343.649206
# 2010    347.967029
# 2011    351.942027
# 2012    357.787305
# 2013    360.985726
# 2014    364.849194
# 2015    368.706601
# 2016           NaN
# dtype: float64

# %%
# calculating the mean for the whole matrix
# Por default lo calcula sobre el axis=0, ya que no tiene sentido hacerlo sobre todo el dataset,
# ya que cada columna tiene diferentes tipos de datos
dataset.mean()
# Out:
# 1960           NaN
# 1961    176.915141
# 1962    180.703231
# 1963    184.572413
# 1964    188.461797
# 1965    192.412363
# 1966    196.145042
# 1967    200.118063
# 1968    203.879464
# 1969    207.336102
# 1970    210.607871
# 1971    213.489694
# 1972    215.998475
# 1973    218.438708
# 1974    220.621210
# 1975    223.046375
# 1976    224.960258
# 1977    227.006734
# 1978    229.187306
# 1979    232.510772
# 1980    236.185357
# 1981    240.789508
# 1982    246.175178
# 1983    251.342389
# 1984    256.647822
# 1985    261.680751
# 1986    266.647038
# 1987    271.768300
# 1988    276.813259
# 1989    281.850054
# 1990    286.062387
# 1991    288.292566
# 1992    293.305416
# 1993    297.759160
# 1994    302.275463
# 1995    304.537276
# 1996    309.714948
# 1997    313.896935
# 1998    320.405981
# 1999    324.004669
# 2000    327.270760
# 2001    312.259570
# 2002    313.269043
# 2003    315.847613
# 2004    317.746559
# 2005    322.669534
# 2006    326.907971
# ...

# %% [markdown]
# ### Using pandas to compute mean, median and variance

# %%
# First two rows 
dataset[0:2]
# Out:
#              Country Code                                     Indicator Name  \
# Country Name
# Aruba                 ABW  Population density (people per sq. km of land ...
# Andorra               AND  Population density (people per sq. km of land ...
#
#              Indicator Code  1960        1961        1962        1963  \
# Country Name
# Aruba           EN.POP.DNST   NaN  307.972222  312.366667  314.983333
# Andorra         EN.POP.DNST   NaN   30.587234   32.714894   34.914894
#
#                     1964        1965        1966  ...        2007        2008  \
# Country Name                                      ...
# Aruba         316.827778  318.666667  320.622222  ...  562.322222  563.011111
# Andorra        37.170213   39.470213   41.800000  ...  180.591489  182.161702
#
#                     2009        2010        2011        2012        2013  \
# Country Name
# Aruba         563.422222  564.427778  566.311111  568.850000  571.783333
# ...

# %%
# index the third row and using axis compute the mean in the row
# iloc allow us to use the index as an integer
dataset.iloc[[2]].mean(axis=1)
# Out:
# Country Name
# Afghanistan    25.373379
# dtype: float64

# %%
# Compute the mean for the last row
dataset.iloc[[-1]].mean(axis=1)
# Out:
# Country Name
# Zimbabwe    24.520532
# dtype: float64

# %%
# With loc we can index a row with the label
dataset.loc[["Germany"]].mean(axis=1)
# Out:
# Country Name
# Germany    227.773688
# dtype: float64

# %%
# compute the median for the last row
dataset.iloc[[-1]].median(axis=1)
# Out:
# Country Name
# Zimbabwe    25.505431
# dtype: float64

# %%
# Compute the median for the last thre countries in the dataset
dataset[-3:].median(axis=1)
# Out:
# Country Name
# Congo, Dem. Rep.    14.419050
# Zambia              10.352668
# Zimbabwe            25.505431
# dtype: float64

# %%
# Compute the median for the 10 rows 
dataset.head(10).median(axis=1)
# Out:
# Country Name
# Aruba                   348.022222
# Andorra                 107.300000
# Afghanistan              19.998926
# Angola                    8.458253
# Albania                 106.001058
# Arab World               15.307283
# United Arab Emirates     19.305072
# Argentina                11.618238
# Armenia                 105.898033
# American Samoa          220.245000
# dtype: float64

# %%
# it has to be the same as
dataset[:10].median(axis=1)
# Out:
# Country Name
# Aruba                   348.022222
# Andorra                 107.300000
# Afghanistan              19.998926
# Angola                    8.458253
# Albania                 106.001058
# Arab World               15.307283
# United Arab Emirates     19.305072
# Argentina                11.618238
# Armenia                 105.898033
# American Samoa          220.245000
# dtype: float64

# %%
# Compute the variance of the dataset and return only the last 5 columns
dataset.var().tail()
# Out:
# 2012    3.063475e+06
# 2013    3.094597e+06
# 2014    3.157111e+06
# 2015    3.220634e+06
# 2016             NaN
# dtype: float64

# %%
# Compute the variance of the dataset but for rows instead of columns and return only the last 5
dataset.var(axis=1).tail()
# Out:
# Country Name
# Yemen, Rep.         167.395631
# South Africa         88.468099
# Congo, Dem. Rep.     62.352027
# Zambia               25.865800
# Zimbabwe             87.068470
# dtype: float64

# %%
# NumPy pandas interoperability
import numpy as np
print("pandas", dataset["2015"].mean())
print("numpy", np.mean(dataset["2015"]))
# Out:
# pandas 368.70660104001837
# numpy 368.70660104001837

# %% [markdown]
# ### Indexing, Slicing and Iterating

# %% [markdown]
# #### Indexing

# %%
dataset.loc[['United States']]
# Out:
#               Country Code                                     Indicator Name  \
# Country Name
# United States          USA  Population density (people per sq. km of land ...
#
#               Indicator Code  1960      1961       1962       1963       1964  \
# Country Name
# United States    EN.POP.DNST   NaN  20.05588  20.366723  20.661953  20.950959
#
#                     1965       1966  ...       2007       2008       2009  \
# Country Name                         ...
# United States  21.214527  21.460952  ...  32.878611  33.243687  33.536399
#
#                     2010       2011       2012       2013       2014  \
# Country Name
# United States  33.817936  34.077243  34.337838  34.591983  34.863098
#
#                     2015  2016
# Country Name
# United States  35.137648   NaN
#
# [1 rows x 60 columns]

# %%
dataset.iloc[[-2]]
# Out:
#              Country Code                                     Indicator Name  \
# Country Name
# Zambia                ZMB  Population density (people per sq. km of land ...
#
#              Indicator Code  1960      1961      1962      1963      1964  \
# Country Name
# Zambia          EN.POP.DNST   NaN  4.227724  4.359305  4.496824  4.639914
#
#                   1965      1966  ...       2007       2008       2009  \
# Country Name                      ...
# Zambia        4.788452  4.942343  ...  17.135926  17.641587  18.170609
#
#                    2010       2011       2012       2013       2014      2015  \
# Country Name
# Zambia        18.721585  19.294752  19.890745  20.508866  21.148177  21.80789
#
#               2016
# Country Name
# Zambia         NaN
#
# [1 rows x 60 columns]

# %%
dataset['2000'].head()
# Out:
# Country Name
# Aruba          504.766667
# Andorra        139.146809
# Afghanistan     30.177894
# Angola          12.078798
# Albania        112.738212
# Name: 2000, dtype: float64

# %%
# with the double bracket notation we return a dataframe object
# Como primero seleccionamos todos las filas y el año 2000 y retorna un DF podemos encadenar la seleccion de India
dataset[['2000']].loc[['India']]
# Out:
#                     2000
# Country Name
# India         354.326858

# %%
# with the single bracket notation we return a data series object
dataset['2000'].loc['India']
# Out:
# 354.326858357522

# %% [markdown]
# #### Slicing

# %%
# slicing countries of rows 2 to 5
dataset.iloc[1:5]
# Out:
#              Country Code                                     Indicator Name  \
# Country Name
# Andorra               AND  Population density (people per sq. km of land ...
# Afghanistan           AFG  Population density (people per sq. km of land ...
# Angola                AGO  Population density (people per sq. km of land ...
# Albania               ALB  Population density (people per sq. km of land ...
#
#              Indicator Code  1960       1961       1962       1963       1964  \
# Country Name
# Andorra         EN.POP.DNST   NaN  30.587234  32.714894  34.914894  37.170213
# Afghanistan     EN.POP.DNST   NaN  14.038148  14.312061  14.599692  14.901579
# Angola          EN.POP.DNST   NaN   4.305195   4.384299   4.464433   4.544558
# Albania         EN.POP.DNST   NaN  60.576642  62.456898  64.329234  66.209307
#
#                    1965       1966  ...        2007        2008        2009  \
# Country Name                        ...
# ...

# %%
dataset.loc[["Germany", "Singapore", "United States", "India"]]
# Out:
#               Country Code                                     Indicator Name  \
# Country Name
# Germany                DEU  Population density (people per sq. km of land ...
# Singapore              SGP  Population density (people per sq. km of land ...
# United States          USA  Population density (people per sq. km of land ...
# India                  IND  Population density (people per sq. km of land ...
#
#               Indicator Code  1960         1961         1962         1963  \
# Country Name
# Germany          EN.POP.DNST   NaN   210.172807   212.029284   214.001527
# Singapore        EN.POP.DNST   NaN  2540.895522  2612.238806  2679.104478
# United States    EN.POP.DNST   NaN    20.055880    20.366723    20.661953
# India            EN.POP.DNST   NaN   154.275864   157.424902   160.679256
#
#                       1964         1965         1966  ...         2007  \
# Country Name                                          ...
# ...

# %%
# Encadenamos la seleccion, primero seleccionamos todas las filas con dichos paises y luego las columnas deseadas
country_list = ["Germany", "Singapore", "United States", "India"]
dataset.loc[country_list][["1970", "1990", "2010"]]
# Out:
#                       1970         1990         2010
# Country Name
# Germany         223.897371   227.517054   234.606908
# Singapore      3096.268657  4547.958209  7231.811966
# United States    22.388131    27.254514    33.817936
# India           186.312757   292.817404   414.028200

# %% [markdown]
# #### Iterating

# %%
for index, row in dataset.iterrows():
    # only printing the rows until Angola
    if index == 'Angola':
        break
    print(index, '\n', row[["Country Code", "1970", "1990", "2010"]], '\n')
# Out:
# Aruba
#  Country Code        ABW
# 1970            328.139
# 1990            345.267
# 2010            564.428
# Name: Aruba, dtype: object
#
# Andorra
#  Country Code        AND
# 1970            51.6574
# 1990            115.981
# 2010            179.615
# Name: Andorra, dtype: object
#
# Afghanistan
#  Country Code        AFG
# 1970            17.0344
# 1990            18.4842
# 2010            42.8303
# Name: Afghanistan, dtype: object

# %% [markdown]
# ### Filtering, sorting and reshaping
# #### Filtering

# %%
# filtering columns 1961, 2000, and 2015
dataset.filter(items=["1961", "2000", "2015"]).head()
# Out:
#                     1961        2000        2015
# Country Name
# Aruba         307.972222  504.766667  577.161111
# Andorra        30.587234  139.146809  149.942553
# Afghanistan    14.038148   30.177894   49.821649
# Angola          4.305195   12.078798   20.070565
# Albania        60.576642  112.738212  105.444051

# %%
# filtering countries that had a greater population density than 500 in 2000
dataset[(dataset["2000"] > 500)][["2000"]]
# Out:
#                                    2000
# Country Name
# Aruba                        504.766667
# Bangladesh                  1008.532988
# Bahrain                      939.232394
# Bermuda                     1236.660000
# Barbados                     627.530233
# Channel Islands              766.623711
# Gibraltar                   2735.100000
# Hong Kong SAR, China        6347.619048
# Macao SAR, China           21595.350000
# St. Martin (French part)     521.764706
# Monaco                     16040.500000
# Maldives                     953.333333
# Malta                       1191.759375
# Mauritius                    584.666502
# Nauru                        502.100000
# Singapore                   6011.771642
# Sint Maarten (Dutch part)    897.617647

# %%
#Get columns that start with 2
dataset.filter(regex="^2", axis=1).head()
# Out:
#                     2000        2001        2002        2003        2004  \
# Country Name
# Aruba         504.766667  516.077778  527.750000  538.972222  548.566667
# Andorra       139.146809  144.191489  151.161702  159.112766  166.674468
# Afghanistan    30.177894   31.448029   32.912231   34.475030   35.995236
# Angola         12.078798   12.483188   12.921871   13.388462   13.873025
# Albania       112.738212  111.685146  111.350730  110.934891  110.472226
#
#                     2005        2006        2007        2008        2009  \
# Country Name
# Aruba         555.727778  560.166667  562.322222  563.011111  563.422222
# Andorra       172.814894  177.389362  180.591489  182.161702  181.859574
# Afghanistan    37.373936   38.574296   39.637202   40.634655   41.674005
# Angola         14.368286   14.872437   15.387749   15.915819   16.459536
# Albania       109.908285  109.217044  108.394781  107.566204  106.843759
#
# ...

# %%
# Filter rows that start with A
dataset.filter(regex="^A", axis=0).head()
# Out:
#              Country Code                                     Indicator Name  \
# Country Name
# Aruba                 ABW  Population density (people per sq. km of land ...
# Andorra               AND  Population density (people per sq. km of land ...
# Afghanistan           AFG  Population density (people per sq. km of land ...
# Angola                AGO  Population density (people per sq. km of land ...
# Albania               ALB  Population density (people per sq. km of land ...
#
#              Indicator Code  1960        1961        1962        1963  \
# Country Name
# Aruba           EN.POP.DNST   NaN  307.972222  312.366667  314.983333
# Andorra         EN.POP.DNST   NaN   30.587234   32.714894   34.914894
# Afghanistan     EN.POP.DNST   NaN   14.038148   14.312061   14.599692
# Angola          EN.POP.DNST   NaN    4.305195    4.384299    4.464433
# Albania         EN.POP.DNST   NaN   60.576642   62.456898   64.329234
#
# ...

# %%
#Filter the countries that has land in their names
dataset.filter(like="land", axis=0).head()
# Out:
#                 Country Code  \
# Country Name
# Switzerland              CHE
# Channel Islands          CHI
# Cayman Islands           CYM
# Finland                  FIN
# Faroe Islands            FRO
#
#                                                     Indicator Name  \
# Country Name
# Switzerland      Population density (people per sq. km of land ...
# Channel Islands  Population density (people per sq. km of land ...
# Cayman Islands   Population density (people per sq. km of land ...
# Finland          Population density (people per sq. km of land ...
# Faroe Islands    Population density (people per sq. km of land ...
#
#                 Indicator Code  1960        1961        1962        1963  \
# Country Name
# Switzerland        EN.POP.DNST   NaN  137.479609  141.009285  144.056036
# Channel Islands    EN.POP.DNST   NaN  569.067010  574.551546  580.386598
# Cayman Islands     EN.POP.DNST   NaN   33.441667   33.925000   34.283333
# ...

# %% [markdown]
# #### Sorting

# %%
# Sort ascending the values in 1961, return only the column 1961 
dataset.sort_values(by=["1961"])[["1961"]].head(10)
# Out:
#                           1961
# Country Name
# Greenland             0.098625
# Mongolia              0.632212
# Namibia               0.749775
# Libya                 0.843320
# Mauritania            0.856916
# Botswana              0.946793
# United Arab Emirates  1.207955
# Australia             1.364565
# Iceland               1.785825
# Oman                  1.825186

# %%
# Sort ascending the values in 2015, return only the column 2015 
dataset.sort_values(by=["2015"])[["2015"]].head(10)
# Out:
#                   2015
# Country Name
# Greenland     0.136713
# Mongolia      1.904744
# Namibia       2.986590
# Australia     3.095579
# Iceland       3.299980
# Suriname      3.480609
# Libya         3.568227
# Guyana        3.896800
# Canada        3.942567
# Mauritania    3.946409

# %%
# Sort descending the values in 2015, return only the column 2015 
dataset.sort_values(by=["2015"], ascending=False)[["2015"]].head(10)
# Out:
#                               2015
# Country Name
# Macao SAR, China      19392.937294
# Monaco                18865.500000
# Singapore              7828.857143
# Hong Kong SAR, China   6957.809524
# Gibraltar              3221.700000
# Bahrain                1788.619481
# Maldives               1363.876667
# Malta                  1347.915625
# Bermuda                1304.700000
# Bangladesh             1236.810648

# %% [markdown]
# #### Reshaping

# %%
# reshaping to 2015 as row and country codes as columns
dataset_2015 = dataset[["Country Code", "2015"]]
dataset_2015.pivot(index=["2015"] * len(dataset_2015),
                   columns="Country Code",
                   values="2015")
# Out:
# Country Code         ABW        AFG        AGO         ALB         AND  \
# 2015          577.161111  49.821649  20.070565  105.444051  149.942553
#
# Country Code        ARB        ARE        ARG         ARM     ASM  ...  \
# 2015          28.779858  109.53305  15.864696  105.996207  277.69  ...
#
# Country Code     VGB         VIR         VNM        VUT        WLD        WSM  \
# 2015          200.78  295.925714  295.751927  21.710582  56.627369  68.278445
#
# Country Code        YEM        ZAF       ZMB        ZWE
# 2015          50.821477  45.303251  21.80789  40.332819
#
# [1 rows x 264 columns]
